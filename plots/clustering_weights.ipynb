# %%
import os
import functools
import operator
import concurrent.futures

# %%
import h5py
import numpy as np
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import smatch
import healsparse

# %%
import lib

# %%
def get_weight(weight_dataset, weight_keys=["statistical_weight"]):
    return functools.reduce(
        operator.mul,
        [
            weight_dataset[weight_key][:]
            for weight_key in weight_keys
        ],
    )

# %%
os.environ["IMSIM_DATA"] = "/global/cfs/cdirs/desbalro"
os.environ["MEDS_DIR"] = "/global/cfs/cdirs/desbalro"

# %%
lib.plotting.setup()

# %%
onecolumn_kwargs = {
    "width": 2,
    "height": 2,
    "horizontal_margin": 8/12,
    "vertical_margin": 6/12,
    "gutter": 1,
    "fig_width": 3 + 4/12,
    "fig_height": 3,
}
twocolumn_kwargs = {
    "width": 6,
    "height": 2,
    "margin": 1,
    "gutter": 1,
    "fig_width": 8,
    "fig_height": 4,
}

# %%
shear_step_plus = "g1_slice=0.02__g2_slice=0.00__g1_other=0.00__g2_other=0.00__zlow=0.0__zhigh=6.0"
shear_step_minus = "g1_slice=-0.02__g2_slice=0.00__g1_other=0.00__g2_other=0.00__zlow=0.0__zhigh=6.0"

assert shear_step_plus in lib.const.SHEAR_STEPS
assert shear_step_minus in lib.const.SHEAR_STEPS

# %%
with (
    h5py.File(lib.const.SIM_SHEAR_CATALOGS[shear_step_plus]) as shear_plus,
    h5py.File(lib.const.SIM_SHEAR_CATALOGS[shear_step_minus]) as shear_minus,
):
    tiles = np.intersect1d(
        shear_plus["mdet"]["noshear"]["tilename"][:],
        shear_minus["mdet"]["noshear"]["tilename"][:],
    )

# %%
mdet_mask = lib.util.load_mdet_mask()
mdet_area = mdet_mask.get_valid_area()

# %% [markdown]
# # Clustering

# %%
def accumulate_y6_area(tile, mdet_mask):
    tile_area = lib.util.get_tile_area(
        tile,
        "r",
        shear=None,
        mdet_mask=mdet_mask,
        border=False,
    )

    return tile_area

# %%
def accumulate_sim_area(tile, mdet_mask, shear=None):
    tile_area = lib.util.get_tile_area(
        tile,
        "r",
        shear=shear,
        mdet_mask=mdet_mask,
        border=True,
    )

    return tile_area

# %%
# _area_y6 = {}
_area_sim_plus = {}
_area_sim_minus = {}
with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
    for i, tile in enumerate(tiles):
        # _future = executor.submit(
        #     accumulate_y6_area,
        #     tile,
        #     mdet_mask,
        # )
        # _area_y6[tile] = _future

        _future = executor.submit(
            accumulate_sim_area,
            tile,
            mdet_mask,
            shear="plus",
        )
        _area_sim_plus[tile] = _future

        _future = executor.submit(
            accumulate_sim_area,
            tile,
            mdet_mask,
            shear="minus",
        )
        _area_sim_minus[tile] = _future

# %%
NBINS = 100 
# bins = np.deg2rad(np.geomspace(1e-2, 1e1, NBINS + 1) / 60)
bins = np.geomspace(1e-2, 2e0, NBINS + 1) * 60

# %%
hist_y6 = {}

with (
    h5py.File(f"/pscratch/sd/s/smau/fiducial-neighbors/neighbors_y6.hdf5") as neighbors,
    h5py.File(lib.const.Y6_TOMOGRAPHY_CATALOG) as tomography,
):
    neighbor_distance = np.rad2deg(neighbors["mdet"]["noshear"]["neighbor_distance"][:]) * 60 * 60
    bhat = tomography["sompz"]["noshear"]["bhat"][:]

    for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
        _sel = (bhat == tomographic_bin)
  
        _hist, _ = np.histogram(neighbor_distance[_sel], bins=bins)    
    
        hist_y6[tomographic_bin] = _hist / mdet_area

    del neighbor_distance, bhat

# %%
# _hist_y6 = {}

# with (
#     h5py.File(lib.const.Y6_SHEAR_CATALOG) as shear,
#     h5py.File(f"/pscratch/sd/s/smau/fiducial-neighbors/neighbors_y6.hdf5") as neighbors,
#     h5py.File(lib.const.Y6_TOMOGRAPHY_CATALOG) as tomography,
# ):
#     neighbor_distance = np.rad2deg(neighbors["mdet"]["noshear"]["neighbor_distance"][:]) * 60 * 60
#     tilename = shear["mdet"]["noshear"]["tilename"][:]
#     bhat = tomography["sompz"]["noshear"]["bhat"][:]

#     for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
#         _hist_y6[tomographic_bin] = {}
        
#         for tile in tiles:
#             in_tile = (tilename == tile)
#             in_tomo = (bhat == tomographic_bin)
#             _sel = (in_tile & in_tomo)
      
#             _hist, _ = np.histogram(neighbor_distance[_sel], bins=bins)    
        
#             _hist_y6[tomographic_bin][tile] = _hist

#     del neighbor_distance, tilename, bhat

# %%
def accumulate_hist(tilename, bhat, weight, neighbor_distance, bins, tomographic_bin, tile):
    in_tile = (tilename == tile)
    in_tomo = (bhat == tomographic_bin)
    sel = (in_tile & in_tomo)
    if weight is None:
        weight = np.ones(sel.shape)

    hist, _ = np.histogram(neighbor_distance[sel], bins=bins, weights=weight[sel])
    # if np.sum(weight[sel]) > 0:
    #     _w = weight[sel] / np.sum(weight[sel])
    #     hist, _, _ = stats.binned_statistic(neighbor_distance[sel], _w, statistic="sum", bins=bins)
    # else:
    #     hist = np.zeros(len(bins) - 1)

    return hist

# %%
_hist_sim = {}
_hist_sim_nbr = {}
_hist_sim_w = {}
_hist_sim_nz = {}

with (
    h5py.File(lib.const.SIM_SHEAR_CATALOGS[shear_step_plus]) as shear,
    h5py.File(lib.const.SIM_TOMOGRAPHY_CATALOGS[shear_step_plus]) as tomo,
    h5py.File(lib.const.SIM_WEIGHT_CATALOGS[shear_step_plus]) as weight,
    h5py.File(f"/pscratch/sd/s/smau/fiducial-neighbors/neighbors_{shear_step_plus}.hdf5") as neighbors,
):
    tilename = shear["mdet"]["noshear"]["tilename"][:]
    bhat = tomo["sompz"]["noshear"]["bhat"][:]
    statistical_weight = weight["mdet"]["noshear"]["statistical_weight"][:]
    nz_match = weight["mdet"]["noshear"]["nz_weight"][:]
    w_match = weight["mdet"]["noshear"]["occupancy_weight"][:]
    nbr_match = weight["mdet"]["noshear"]["neighbor_weight"][:]
    neighbor_distance = np.rad2deg(neighbors["mdet"]["noshear"]["neighbor_distance"][:]) * 60 * 60

    with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
        for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
            _hist_sim[tomographic_bin] = {}
            _hist_sim_nbr[tomographic_bin] = {}
            _hist_sim_w[tomographic_bin] = {}
            _hist_sim_nz[tomographic_bin] = {}
            
            for tile in tiles:
                _future = executor.submit(
                    accumulate_hist,
                    tilename,
                    bhat,
                    statistical_weight,
                    neighbor_distance,
                    bins,
                    tomographic_bin,
                    tile,
                )
                _hist_sim[tomographic_bin][tile] = _future
                
                _future = executor.submit(
                    accumulate_hist,
                    tilename,
                    bhat,
                    statistical_weight * nbr_match,
                    neighbor_distance,
                    bins,
                    tomographic_bin,
                    tile,
                )
                _hist_sim_nbr[tomographic_bin][tile] = _future
    
                _future = executor.submit(
                    accumulate_hist,
                    tilename,
                    bhat,
                    statistical_weight * w_match,
                    neighbor_distance,
                    bins,
                    tomographic_bin,
                    tile,
                )
                _hist_sim_w[tomographic_bin][tile] = _future
    
                _future = executor.submit(
                    accumulate_hist,
                    tilename,
                    bhat,
                    statistical_weight * nz_match,
                    neighbor_distance,
                    bins,
                    tomographic_bin,
                    tile,
                )
                _hist_sim_nz[tomographic_bin][tile] = _future
    
    del tilename, bhat, statistical_weight, nbr_match, w_match, nz_match, neighbor_distance

# %%
# hist_y6 = {}
hist_sim = {}
hist_sim_nbr = {}
hist_sim_w = {}
hist_sim_nz = {}

for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
    # _densities_y6 = np.array(
    #     [
    #         _hist_y6[tomographic_bin][tile].result() / _area_y6[tile].result()
    #         for tile in tiles
    #     ]
    # )
    # hist_y6[tomographic_bin] = np.mean(_densities, axis=0)
    
    _densities_sim = np.array(
        [
            _hist_sim[tomographic_bin][tile].result() / _area_sim_plus[tile].result()
            for tile in tiles
        ]
    )
    hist_sim[tomographic_bin] = np.mean(_densities_sim, axis=0)

    _densities_sim_nbr = np.array(
        [
            _hist_sim_nbr[tomographic_bin][tile].result() / _area_sim_plus[tile].result()
            for tile in tiles
        ]
    )
    hist_sim_nbr[tomographic_bin] = np.mean(_densities_sim_nbr, axis=0)

    _densities_sim_w = np.array(
        [
            _hist_sim_w[tomographic_bin][tile].result() / _area_sim_plus[tile].result()
            for tile in tiles
        ]
    )
    hist_sim_w[tomographic_bin] = np.mean(_densities_sim_w, axis=0)

    _densities_sim_nz = np.array(
        [
            _hist_sim_nz[tomographic_bin][tile].result() / _area_sim_plus[tile].result()
            for tile in tiles
        ]
    )
    hist_sim_nz[tomographic_bin] = np.mean(_densities_sim_nz, axis=0)

    # hist_sim[tomographic_bin] = np.mean(
    #     [
    #         _hist_sim[tomographic_bin][tile].result()
    #         for tile in tiles
    #     ],
    #     axis=0,
    # ) / np.mean(
    #     [
    #         _area[tile].result()
    #         for tile in tiles
    #     ],
    #     axis=0,
    # )

    # hist_sim_weighted[tomographic_bin] = np.mean(
    #     [
    #         _hist_sim_weighted[tomographic_bin][tile].result()
    #         for tile in tiles
    #     ],
    #     axis=0,
    # ) / np.mean(
    #     [
    #         _area[tile].result()
    #         for tile in tiles
    #     ],
    #     axis=0,
    # )

    # _hmean_weights = np.where(np.array([v.result() for v in _hist_sim[tomographic_bin].values()]) > 0, 1, np.nan)
    # hist_sim[tomographic_bin] = stats.hmean(
    #     np.array([
    #         hist_res.result() / area_res.result()
    #         for (hist_res, area_res)
    #         in zip(_hist_sim[tomographic_bin].values(), _area.values())
    #     ]),
    #     axis=0,
    #     weights=_hmean_weights,
    #     nan_policy="omit",
    # ) * np.isfinite(_hmean_weights).sum() / np.isnan(_hmean_weights).sum()

    # _hmean_weights_weighted = np.where(np.array([v.result() for v in _hist_sim_weighted[tomographic_bin].values()]) > 0, 1, np.nan)
    # hist_sim_weighted[tomographic_bin] = stats.hmean(
    #     np.array([
    #         hist_res.result() / area_res.result()
    #         for (hist_res, area_res)
    #         in zip(_hist_sim_weighted[tomographic_bin].values(), _area.values())
    #     ]),
    #     axis=0,
    #     weights=_hmean_weights_weighted,
    #     nan_policy="omit",
    # ) * np.isfinite(_hmean_weights_weighted).sum() / np.isnan(_hmean_weights_weighted).sum()

# %%
fig, axs = plt.subplots(1, len(lib.const.TOMOGRAPHIC_BINS), sharex=True, sharey=True, figsize=(7, 3), constrained_layout=True)

for i in lib.const.TOMOGRAPHIC_BINS:
    axs[i].stairs(
        hist_y6[i],
        edges=bins,
        label="Y6",
    )
    axs[i].stairs(
        hist_sim[i],
        edges=bins,
        label="sim",
    )
    axs[i].stairs(
        hist_sim_nbr[i],
        edges=bins,
        label="sim [nbr-match]",
    )
    axs[i].stairs(
        hist_sim_w[i],
        edges=bins,
        label="sim [w-match]",
    )
    axs[i].stairs(
        hist_sim_nz[i],
        edges=bins,
        label="sim [nz-match]",
    )


axs[0].set_xscale("log")
# plt.xlim(0, None)
axs[0].legend(loc="upper left")

fig.supxlabel("nearest neighbor distance [arcsec]")
fig.supylabel("density [$counts / deg^2$]")

plt.show()

# %%
fig, axs = plt.subplots(1, len(lib.const.TOMOGRAPHIC_BINS), sharex=True, sharey=True, figsize=(7, 3), constrained_layout=True)

for i in lib.const.TOMOGRAPHIC_BINS:
    axs[i].stairs(
        hist_y6[i] / np.sum(hist_y6[i]),
        edges=bins,
        label="Y6",
    )
    axs[i].stairs(
        hist_sim[i] / np.sum(hist_sim[i]),
        edges=bins,
        label="sim",
    )
    axs[i].stairs(
        hist_sim_nbr[i] / np.sum(hist_sim_nbr[i]),
        edges=bins,
        label="sim [nbr-match]",
    )
    axs[i].stairs(
        hist_sim_w[i] / np.sum(hist_sim_w[i]),
        edges=bins,
        label="sim [w-match]",
    )
    axs[i].stairs(
        hist_sim_nz[i] / np.sum(hist_sim_nz[i]),
        edges=bins,
        label="sim [nz-match]",
    )

axs[0].set_xscale("log")
# plt.xlim(0, None)
axs[0].legend(loc="upper left")

fig.supxlabel("nearest neighbor distance [arcsec]")
fig.supylabel("normalized density")

plt.show()

# %%
tomo_colors = {
    0: "#3BB470",
    1: "#FA7F72",
    2: "#DD9FDD",
    3: "#6495EC",
}

fig, axs = plt.subplots(
    2, len(lib.const.TOMOGRAPHIC_BINS),
    figsize=(7, 6),
    sharex=True,
    sharey="row",
)
fig.subplots_adjust(wspace=0)

for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
    lib.plotting.contour1d(
        axs[0, tomographic_bin],
        hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin]),
        bins,
        log=True,
        # c=tomo_colors[tomographic_bin],
        c="k",
        ls=":",
        label="Y6",
    )
    lib.plotting.contour1d(
        axs[0, tomographic_bin],
        hist_sim[tomographic_bin] / np.sum(hist_sim[tomographic_bin]),
        bins,
        log=True,
        c=tomo_colors[tomographic_bin],
        ls="--",
        label="sim",
    )
    lib.plotting.contour1d(
        axs[0, tomographic_bin],
        hist_sim_nbr[tomographic_bin] / np.sum(hist_sim_nbr[tomographic_bin]),
        bins,
        log=True,
        c=tomo_colors[tomographic_bin],
        ls="-",
        label="sim [nbr-match]",
    )
    
    axs[1, tomographic_bin].axhline(
        1,
        # c=tomo_colors[tomographic_bin],
        c="k",
        ls=":",
        # label="Y6",
    )
    lib.plotting.contour1d(
        axs[1, tomographic_bin],
        (hist_sim[tomographic_bin] / np.sum(hist_sim[tomographic_bin])) / (hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin])),
        bins,
        log=True,
        c=tomo_colors[tomographic_bin],
        ls="--",
        label="sim",
    )
    lib.plotting.contour1d(
        axs[1, tomographic_bin],
        (hist_sim_nbr[tomographic_bin] / np.sum(hist_sim_nbr[tomographic_bin])) / (hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin])),
        bins,
        log=True,
        c=tomo_colors[tomographic_bin],
        ls="-",
        label="sim [nbr-match]",
    )
    
# axs[0, 0].legend(loc="upper left")
# axs[1, 0].legend(loc="upper left")

axs[0, 0].set_xscale("log")
axs[0, 0].xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
axs[0, 0].set_ylim(0, None)

axs[1, 0].set_ylim(0.5, 1.5)

fig.supxlabel("nearest neighbor distance [arcsec]")

# axs[0, 0].set_ylabel("density [$counts / deg^2$]")
axs[0, 0].set_ylabel("normalized density")
axs[1, 0].set_ylabel("relative density")

lines = [
    mpl.lines.Line2D([0], [0], color="k", linestyle=ls)
    for ls in [":", "--", "-"]
]
labels = ["Y6", "sim", "sim [nbr-match]"]
axs[1, 3].legend(lines, labels, loc="upper left")

lib.plotting.watermark(fig)

# fig.savefig("tomographic-clustering.pdf")

plt.show()

# %%
tomo_colors = {
    0: "#3BB470",
    1: "#FA7F72",
    2: "#DD9FDD",
    3: "#6495EC",
}

fig, axs = plt.subplots(
    4, 4,
    figsize=(7, 6),
    sharex=True,
    sharey=True,
)
fig.subplots_adjust(wspace=0, hspace=0)

for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
    axs[tomographic_bin, 0].stairs(
        hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin]),
        bins,
        ec="k",
        ls=":",
        label="Y6",
    )
    axs[tomographic_bin, 0].stairs(
        hist_sim[tomographic_bin] / np.sum(hist_sim[tomographic_bin]),
        bins,
        ec=tomo_colors[tomographic_bin],
        ls="-",
        label="sim",
    )

    axs[tomographic_bin, 1].stairs(
        hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin]),
        bins,
        ec="k",
        ls=":",
        label="Y6",
    )
    axs[tomographic_bin, 1].stairs(
        hist_sim_nbr[tomographic_bin] / np.sum(hist_sim_nbr[tomographic_bin]),
        bins,
        ec=tomo_colors[tomographic_bin],
        ls="-",
        label="sim [nbr-match]",
    )

    axs[tomographic_bin, 2].stairs(
        hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin]),
        bins,
        ec="k",
        ls=":",
        label="Y6",
    )
    axs[tomographic_bin, 2].stairs(
        hist_sim_w[tomographic_bin] / np.sum(hist_sim_w[tomographic_bin]),
        bins,
        ec=tomo_colors[tomographic_bin],
        ls="-",
        label="sim [w-match]",
    )

    axs[tomographic_bin, 3].stairs(
        hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin]),
        bins,
        ec="k",
        ls=":",
        label="Y6",
    )
    axs[tomographic_bin, 3].stairs(
        hist_sim_nz[tomographic_bin] / np.sum(hist_sim_nz[tomographic_bin]),
        bins,
        ec=tomo_colors[tomographic_bin],
        ls="-",
        label="sim [nz-match]",
    )
    
axs[0, 0].set_ylabel("0")
axs[1, 0].set_ylabel("1")
axs[2, 0].set_ylabel("2")
axs[3, 0].set_ylabel("3")

axs[0, 1].set_title("nbr-match")
axs[0, 2].set_title("w-match")
axs[0, 3].set_title("nz-match")

axs[0, 0].legend(loc="upper left")

axs[0, 0].set_xscale("log")
axs[0, 0].xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
axs[0, 0].set_ylim(0, None)


fig.supxlabel("nearest neighbor distance [arcsec]")


lib.plotting.watermark(fig)

# fig.savefig("clustering.pdf")

plt.show()

# %%
tomo_colors = {
    0: "#3BB470",
    1: "#FA7F72",
    2: "#DD9FDD",
    3: "#6495EC",
}

fig, axs = plt.subplots(
    4, 4,
    figsize=(7, 6),
    sharex=True,
    sharey=True,
)
fig.subplots_adjust(wspace=0, hspace=0)

for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
    lib.plotting.contour1d(
        axs[tomographic_bin, 0],
        hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin]),
        bins,
        log=True,
        # c=tomo_colors[tomographic_bin],
        c="k",
        ls=":",
        label="Y6",
    )
    lib.plotting.contour1d(
        axs[tomographic_bin, 0],
        hist_sim[tomographic_bin] / np.sum(hist_sim[tomographic_bin]),
        bins,
        log=True,
        c=tomo_colors[tomographic_bin],
        ls="-",
        label="sim",
    )

    lib.plotting.contour1d(
        axs[tomographic_bin, 1],
        hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin]),
        bins,
        log=True,
        # c=tomo_colors[tomographic_bin],
        c="k",
        ls=":",
        label="Y6",
    )
    lib.plotting.contour1d(
        axs[tomographic_bin, 1],
        hist_sim_nbr[tomographic_bin] / np.sum(hist_sim_nbr[tomographic_bin]),
        bins,
        log=True,
        c=tomo_colors[tomographic_bin],
        ls="-",
        label="sim [nbr-match]",
    )

    lib.plotting.contour1d(
        axs[tomographic_bin, 2],
        hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin]),
        bins,
        log=True,
        # c=tomo_colors[tomographic_bin],
        c="k",
        ls=":",
        label="Y6",
    )
    lib.plotting.contour1d(
        axs[tomographic_bin, 2],
        hist_sim_w[tomographic_bin] / np.sum(hist_sim_w[tomographic_bin]),
        bins,
        log=True,
        c=tomo_colors[tomographic_bin],
        ls="-",
        label="sim [w-match]",
    )

    lib.plotting.contour1d(
        axs[tomographic_bin, 3],
        hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin]),
        bins,
        log=True,
        # c=tomo_colors[tomographic_bin],
        c="k",
        ls=":",
        label="Y6",
    )
    lib.plotting.contour1d(
        axs[tomographic_bin, 3],
        hist_sim_nz[tomographic_bin] / np.sum(hist_sim_nz[tomographic_bin]),
        bins,
        log=True,
        c=tomo_colors[tomographic_bin],
        ls="-",
        label="sim [nz-match]",
    )
    
axs[0, 0].set_ylabel("0")
axs[1, 0].set_ylabel("1")
axs[2, 0].set_ylabel("2")
axs[3, 0].set_ylabel("3")

axs[0, 1].set_title("nbr-match")
axs[0, 2].set_title("w-match")
axs[0, 3].set_title("nz-match")

axs[0, 0].legend(loc="upper left")

axs[0, 0].set_xscale("log")
axs[0, 0].xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
axs[0, 0].set_ylim(0, None)


fig.supxlabel("nearest neighbor distance [arcsec]")


lib.plotting.watermark(fig)

# fig.savefig("clustering.pdf")

plt.show()

# %%
tomo_colors = {
    0: "#3BB470",
    1: "#FA7F72",
    2: "#DD9FDD",
    3: "#6495EC",
}

# fig, axs = plt.subplots(
#     4, 1,
#     figsize=(7, 6),
#     sharex=True,
#     sharey=True,
# )
# fig.subplots_adjust(wspace=0, hspace=0)
fig, axs = plt.subplots(4, 1, figsize=(3, 6), sharex=True, sharey=True, constrained_layout=True)

for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
    axs[tomographic_bin].axhline(
        1,
        c="k",
        ls=":",
        label="Y6",
    )
    axs[tomographic_bin].stairs(
        hist_sim[tomographic_bin] / np.sum(hist_sim[tomographic_bin]) / (hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin])),
        bins,
        ec="k",
        ls="-",
        label="sim",
    )

    axs[tomographic_bin].stairs(
        hist_sim_nbr[tomographic_bin] / np.sum(hist_sim_nbr[tomographic_bin]) / (hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin])),
        bins,
        ec="darkseagreen",
        ls="-",
        label="sim [nbr-match]",
    )

    axs[tomographic_bin].stairs(
        hist_sim_w[tomographic_bin] / np.sum(hist_sim_w[tomographic_bin]) / (hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin])),
        bins,
        ec="cornflowerblue",
        ls="-",
        label="sim [w-match]",
    )

    axs[tomographic_bin].stairs(
        hist_sim_nz[tomographic_bin] / np.sum(hist_sim_nz[tomographic_bin]) / (hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin])),
        bins,
        ec="lightcoral",
        ls="-",
        label="sim [nz-match]",
    )
    
    axs[tomographic_bin].set_ylabel(tomographic_bin)


# axs[0, 1].set_title("nbr-match")
# axs[0, 2].set_title("w-match")
# axs[0, 3].set_title("nz-match")

axs[0].legend(loc="upper right")

axs[0].set_xscale("log")
axs[0].xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
axs[0].set_ylim(0, 2)
# axs[0].set_yticks(np.arange(0.2, 2, 0.4))


fig.supxlabel("nearest neighbor distance [arcsec]")


lib.plotting.watermark(fig)

# fig.savefig("clustering.pdf")

plt.show()

# %%
tomo_colors = {
    0: "#3BB470",
    1: "#FA7F72",
    2: "#DD9FDD",
    3: "#6495EC",
}

# fig, axs = plt.subplots(
#     4, 1,
#     figsize=(7, 6),
#     sharex=True,
#     sharey=True,
# )
# fig.subplots_adjust(wspace=0, hspace=0)
fig, axs = plt.subplots(2, 2, figsize=(7, 6), sharex=True, sharey=True, constrained_layout=True)
axs = axs.ravel()

for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
    axs[tomographic_bin].axhline(
        1,
        c="k",
        ls=":",
        # label="Y6",
    )
    axs[tomographic_bin].stairs(
        hist_sim[tomographic_bin] / np.sum(hist_sim[tomographic_bin]) / (hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin])),
        bins,
        ec="k",
        ls="-",
        label="sim",
    )

    axs[tomographic_bin].stairs(
        hist_sim_nbr[tomographic_bin] / np.sum(hist_sim_nbr[tomographic_bin]) / (hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin])),
        bins,
        ec="darkseagreen",
        ls="-",
        label="nbr-match",
    )

    axs[tomographic_bin].stairs(
        hist_sim_w[tomographic_bin] / np.sum(hist_sim_w[tomographic_bin]) / (hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin])),
        bins,
        ec="cornflowerblue",
        ls="-",
        label="w-match",
    )

    axs[tomographic_bin].stairs(
        hist_sim_nz[tomographic_bin] / np.sum(hist_sim_nz[tomographic_bin]) / (hist_y6[tomographic_bin] / np.sum(hist_y6[tomographic_bin])),
        bins,
        ec="lightcoral",
        ls="-",
        label="nz-match",
    )
    
    axs[tomographic_bin].set_title(f"Bin {tomographic_bin}")
    axs[tomographic_bin].set_box_aspect(1)


# axs[0, 1].set_title("nbr-match")
# axs[0, 2].set_title("w-match")
# axs[0, 3].set_title("nz-match")

axs[-1].legend(loc="lower right")

axs[0].set_xscale("log")
axs[0].xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
# axs[0].set_ylim(0, 2)
# axs[0].set_yticks(np.arange(0.2, 2, 0.4))

fig.supylabel("$sim / Y6$")
fig.supxlabel("nearest neighbor distance [arcsec]")
fig.suptitle("Clustering Weights")

lib.plotting.watermark(fig)

fig.savefig("clustering_weights.pdf")

plt.show()
