# %%
import functools
import os

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats

# %%
import lib

# %%
def watermark(
    fig,
    text="preliminary",
):
    fig_width, fig_height = fig.get_size_inches()
    angle = np.degrees(np.arctan2(fig_height, fig_width))
    size = np.hypot(fig_width, fig_height) * 6 
    fig.text(
        0.5,
        0.5,
        text,
        color="k",
        alpha=0.1,
        fontsize=size,
        rotation=angle,
        horizontalalignment="center",
        verticalalignment="center",
    )

    return None

# %%
shear_step = "g1_slice=0.02__g2_slice=0.00__g1_other=0.00__g2_other=0.00__zlow=0.0__zhigh=6.0"

# %%
redshift_sim = h5py.File(
    os.path.join(
        "/global/cfs/cdirs/des/boyan/sompz_output/y6_imsim_1000Tile/",
        shear_step,
        "noshear/weighted_pile3_oldtomo/sompz_y6_sim_noshear_1000Tile.hdf5",
    )
)

# %%
shear_sim = h5py.File(
    lib.const.IMSIM_CATALOGS[shear_step],
)

# %%
truth_match = h5py.File(
    lib.const.MATCH_CATALOGS[shear_step],
)

# %%
_, shear_sim_index, redshift_sim_index = np.intersect1d(
    shear_sim["mdet/noshear"]["uid"],
    redshift_sim["catalog/sompz/noshear"]["coadd_object_id"],
    return_indices=True,
)

# %%
np.testing.assert_equal(
    shear_sim["mdet/noshear"]["uid"][:][shear_sim_index],
    redshift_sim["catalog/sompz/noshear"]["coadd_object_id"][:][redshift_sim_index],
)

# %%
bhat_sim = np.full(shear_sim["mdet/noshear"]["uid"].shape, np.nan)
bhat_sim[shear_sim_index] = redshift_sim["catalog/sompz/noshear"]["bhat"][:][redshift_sim_index]

# %%
cell_sim = np.full(shear_sim["mdet/noshear"]["uid"].shape, np.nan)
cell_sim[shear_sim_index] = redshift_sim["catalog/sompz/noshear"]["cell_wide"][:][redshift_sim_index]

# %%
weights_sim = lib.weights.get_shear_weights(shear_sim["mdet/noshear"])

# %%
count_grid_sim, _, _ = stats.binned_statistic(
    cell_sim,
    None,
    statistic="count",
    bins=lib.const.CELL_IDS,
)
occupancy_grid_sim = count_grid_sim / sum(count_grid_sim)

# %%
_weight_grid_sim, _, _ = stats.binned_statistic(
    cell_sim,
    weights_sim,
    statistic="sum",
    bins=lib.const.CELL_IDS,
)
weight_grid_sim = _weight_grid_sim / sum(_weight_grid_sim)

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    occupancy_grid_sim.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    vmin=0,
)
axs.set_title("occupancy [sim]")

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    weight_grid_sim.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    vmin=0,
)
axs.set_title("weight [sim]")

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %% [markdown]
# ---

# %%
shear_y6 = h5py.File(lib.const.Y6_SHEAR_CATALOG)
redshift_y6 = h5py.File(lib.const.Y6_REDSHIFT_CATALOG)

# %%
_, shear_y6_index, redshift_y6_index = np.intersect1d(
    shear_y6["mdet/noshear"]["uid"],
    redshift_y6["sompz/noshear"]["coadd_object_id"],
    return_indices=True,
)

# %%
bhat_y6 = np.full(shear_y6["mdet/noshear"]["uid"].shape, np.nan)
bhat_y6[shear_y6_index] = redshift_y6["sompz/noshear"]["bhat"][:][redshift_y6_index]

# %%
cell_y6 = np.full(shear_y6["mdet/noshear"]["uid"].shape, np.nan)
cell_y6[shear_y6_index] = redshift_y6["sompz/noshear"]["cell_wide"][:][redshift_y6_index]

# %%
weights_y6 = lib.weights.get_shear_weights(shear_y6["mdet/noshear"])

# %%
count_grid_y6, _, _ = stats.binned_statistic(
    cell_y6,
    None,
    statistic="count",
    bins=lib.const.CELL_IDS,
)
occupancy_grid_y6 = count_grid_y6 / sum(count_grid_y6)

# %%
_weight_grid_y6, _, _ = stats.binned_statistic(
    cell_y6,
    weights_y6,
    statistic="sum",
    bins=lib.const.CELL_IDS,
)
weight_grid_y6 = _weight_grid_y6 / sum(_weight_grid_y6)

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    occupancy_grid_y6.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    vmin=0,
)
axs.set_title("occupancy [Y6]")

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    weight_grid_y6.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    vmin=0,
)
axs.set_title("weight [Y6]")

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %% [markdown]
# ---

# %%
fig, axs = plt.subplots(1, 2, figsize=(7, 3))

norm = mpl.colors.Normalize(vmin=0)

axs[0].imshow(
    occupancy_grid_y6.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    norm=norm,
)
axs[0].set_title("Y6")

axs[1].imshow(
    occupancy_grid_sim.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    norm=norm,
)
axs[1].set_title("sim")


for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])

fig.suptitle("occupancy")

watermark(fig)

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(7, 3))

norm = mpl.colors.Normalize(vmin=0)

axs[0].imshow(
    weight_grid_y6.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    norm=norm,
)
axs[0].set_title("Y6")

axs[1].imshow(
    weight_grid_sim.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    norm=norm,
)
axs[1].set_title("sim")


for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])

fig.suptitle("weight")

watermark(fig)

plt.show()

# %%
np.var(occupancy_grid_y6), np.var(occupancy_grid_sim)
# Out:
# (3.671899408447018e-07, 5.205767734140469e-07)

# %%
np.var(weight_grid_y6), np.var(weight_grid_sim)
# Out:
# (2.408401797308064e-07, 3.7646127115587887e-07)

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    (occupancy_grid_y6 / occupancy_grid_sim).reshape(lib.const.SOM_SHAPE),
    origin="lower",
    vmin=0,
)
axs.set_title("occupancy ratio [Y6 / sim]")

fig.colorbar(im, ax=axs)

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    (weight_grid_y6 / weight_grid_sim).reshape(lib.const.SOM_SHAPE),
    origin="lower",
    vmin=0,
)
axs.set_title("weight ratio [Y6 / sim]")

fig.colorbar(im, ax=axs)

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %% [markdown]
# ---

# %%
z_grid_sim, _, _ = stats.binned_statistic(
    cell_sim,
    truth_match["mdet/noshear"]["z"],
    statistic="mean",
    bins=lib.const.CELL_IDS,
)

# %%
z_std_grid_sim, _, _ = stats.binned_statistic(
    cell_sim,
    truth_match["mdet/noshear"]["z"],
    statistic="std",
    bins=lib.const.CELL_IDS,
)

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    z_grid_sim.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    vmin=0,
)
axs.set_title("$〈z〉$ [sim]")

fig.colorbar(im, ax=axs)

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    z_std_grid_sim.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    vmin=0,
)
axs.set_title("$\\sigma_z$ [sim]")

fig.colorbar(im, ax=axs)

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    np.square(z_grid_sim / z_std_grid_sim).reshape(lib.const.SOM_SHAPE),
    origin="lower",
    vmin=0,
)
axs.set_title("$\\mu_z^2 / \\sigma_z^2$ [sim]")

fig.colorbar(im, ax=axs)

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %%
cell_assignments = {}
for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
    cell_assignments[tomographic_bin] = np.unique(
        cell_sim[bhat_sim == tomographic_bin]
    ).astype(int)

assert len(
    functools.reduce(
        np.intersect1d,
        [
            cells
            for cells in cell_assignments.values()
        ],
    )
) == 0

# %%
fig, axs = plt.subplots(1, 4, figsize=(7, 3))

norm = mpl.colors.Normalize(vmin=0, vmax=3)

for tomographic_bin in lib.const.TOMOGRAPHIC_BINS:
    _z = np.zeros_like(z_grid_sim)
    _z[cell_assignments[tomographic_bin]] = z_grid_sim[cell_assignments[tomographic_bin]]

    axs[tomographic_bin].imshow(
        _z.reshape(lib.const.SOM_SHAPE),
        origin="lower",
        norm=norm,
    )
    axs[tomographic_bin].set_title(tomographic_bin)
    
fig.suptitle("$〈z〉$ [sim]")

for ax in axs.ravel():
    ax.set_xticks([])
    ax.set_yticks([])

watermark(fig)

plt.show()

# %% [markdown]
# ---

# %%
gi_color_grid_sim, _, _ = stats.binned_statistic(
    cell_sim,
    -2.5 * np.log10(
        shear_sim["mdet/noshear"]["pgauss_band_flux_g"][:] /
        shear_sim["mdet/noshear"]["pgauss_band_flux_i"][:]
    ),
    statistic="mean",
    bins=lib.const.CELL_IDS,
)

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

gi_norm = mpl.colors.CenteredNorm(lib.const.GI_COLOR)
gi_cmap="RdBu_r"

im = axs.imshow(
    gi_color_grid_sim.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    norm=gi_norm,
    cmap=cmap,
)
axs.set_title("$〈g - i〉$ [sim]")

fig.colorbar(im, ax=axs)

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %%
iz_color_grid_sim, _, _ = stats.binned_statistic(
    cell_sim,
    -2.5 * np.log10(
        shear_sim["mdet/noshear"]["pgauss_band_flux_i"][:] /
        shear_sim["mdet/noshear"]["pgauss_band_flux_z"][:]
    ),
    statistic="mean",
    bins=lib.const.CELL_IDS,
)

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

iz_norm = mpl.colors.CenteredNorm(lib.const.IZ_COLOR)
iz_cmap="RdBu_r"

im = axs.imshow(
    iz_color_grid_sim.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    norm=iz_norm,
    cmap=iz_cmap,
)
axs.set_title("$〈i - z〉$ [sim]")

fig.colorbar(im, ax=axs)

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %%
gi_color_grid_y6, _, _ = stats.binned_statistic(
    cell_y6,
    -2.5 * np.log10(
        shear_y6["mdet/noshear"]["pgauss_band_flux_g"][:] /
        shear_y6["mdet/noshear"]["pgauss_band_flux_i"][:]
    ),
    statistic="mean",
    bins=lib.const.CELL_IDS,
)

# %%
iz_color_grid_y6, _, _ = stats.binned_statistic(
    cell_y6,
    -2.5 * np.log10(
        shear_y6["mdet/noshear"]["pgauss_band_flux_i"][:] /
        shear_y6["mdet/noshear"]["pgauss_band_flux_z"][:]
    ),
    statistic="mean",
    bins=lib.const.CELL_IDS,
)

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    gi_color_grid_y6.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    norm=gi_norm,
    cmap=gi_cmap,
)
axs.set_title("$〈g - i〉$ [Y6]")

fig.colorbar(im, ax=axs)

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()

# %%
fig, axs = plt.subplots(1, 1, figsize=(3 + 4/12, 3))

im = axs.imshow(
    iz_color_grid_y6.reshape(lib.const.SOM_SHAPE),
    origin="lower",
    norm=iz_norm,
    cmap=iz_cmap,
)
axs.set_title("$〈i - z〉$ [Y6]")

fig.colorbar(im, ax=axs)

axs.set_xticks([])
axs.set_yticks([])

watermark(fig)

plt.show()
